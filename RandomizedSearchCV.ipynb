# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop("species",axis=1)
y=df["species"]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn=KNeighborsClassifier(n_neighbors=13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_svc=SVC(C=30,kernel="rbf",gamma='auto')

# %%
model_svc.fit(X_train,y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model_svc.score(X_test,y_test)
# Out:
# 0.98

# %%
#randomizedsearchcv

from sklearn.model_selection import RandomizedSearchCV

# %%
classifier=RandomizedSearchCV((model_svc),{
    'C': [1,10,20,30],
    'kernel':['rbf','linear'],
},n_iter=4, cv=5, return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.0042685 , 0.00493879, 0.00537024, 0.00413337]),
#  'std_fit_time': array([2.53426752e-04, 5.49137758e-04, 1.09336638e-03, 9.15622458e-05]),
#  'mean_score_time': array([0.00344462, 0.00321937, 0.00355983, 0.00312071]),
#  'std_score_time': array([8.34618900e-04, 6.51072206e-05, 5.81373681e-04, 7.99164567e-05]),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'linear'],
#               mask=[False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_C': masked_array(data=[1, 30, 20, 30],
#               mask=[False, False, False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'linear', 'C': 1},
#   {'kernel': 'rbf', 'C': 30},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'linear', 'C': 30}],
#  'split0_test_score': array([0.96666667, 0.96666667, 1.        , 1.        ]),
#  'split1_test_score': array([1., 1., 1., 1.]),
# ...

# %%
results=pd.DataFrame(classifier.cv_results_)

# %%
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.004269      0.000253         0.003445        0.000835       linear
# 1       0.004939      0.000549         0.003219        0.000065          rbf
# 2       0.005370      0.001093         0.003560        0.000581       linear
# 3       0.004133      0.000092         0.003121        0.000080       linear
#
#    param_C                         params  split0_test_score  \
# 0        1   {'kernel': 'linear', 'C': 1}           0.966667
# 1       30     {'kernel': 'rbf', 'C': 30}           0.966667
# 2       20  {'kernel': 'linear', 'C': 20}           1.000000
# 3       30  {'kernel': 'linear', 'C': 30}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.900000           0.933333                1.0
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1       30          rbf         0.960000
# 2       20       linear         0.966667
# 3       30       linear         0.960000

# %%
classifier2=RandomizedSearchCV((model_knn),{
    'n_neighbors': [3,5,7,10],
    'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
}, n_iter=4, cv=5, return_train_score=False)

# %%
classifier2.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#                    n_iter=4,
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'n_neighbors': [3, 5, 7, 10]})

# %%
classifier2.cv_results_
# Out:
# {'mean_fit_time': array([0.00416789, 0.00374036, 0.00379715, 0.0039485 ]),
#  'std_fit_time': array([0.00028891, 0.00012613, 0.00012314, 0.00035971]),
#  'mean_score_time': array([0.00548196, 0.00537887, 0.00521364, 0.00552444]),
#  'std_score_time': array([0.000333  , 0.00044609, 0.00029294, 0.00027693]),
#  'param_n_neighbors': masked_array(data=[3, 7, 5, 3],
#               mask=[False, False, False, False],
#         fill_value=999999),
#  'param_algorithm': masked_array(data=['auto', 'kd_tree', 'auto', 'ball_tree'],
#               mask=[False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'n_neighbors': 3, 'algorithm': 'auto'},
#   {'n_neighbors': 7, 'algorithm': 'kd_tree'},
#   {'n_neighbors': 5, 'algorithm': 'auto'},
#   {'n_neighbors': 3, 'algorithm': 'ball_tree'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667]),
# ...

# %%
results2=pd.DataFrame(classifier2.cv_results_)

# %%
results2.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004168      0.000289         0.005482        0.000333
# 1       0.003740      0.000126         0.005379        0.000446
# 2       0.003797      0.000123         0.005214        0.000293
# 3       0.003948      0.000360         0.005524        0.000277
#
#    param_n_neighbors param_algorithm  \
# 0                  3            auto
# 1                  7         kd_tree
# 2                  5            auto
# 3                  3       ball_tree
#
#                                          params  split0_test_score  \
# 0       {'n_neighbors': 3, 'algorithm': 'auto'}           0.966667
# 1    {'n_neighbors': 7, 'algorithm': 'kd_tree'}           0.966667
# 2       {'n_neighbors': 5, 'algorithm': 'auto'}           0.966667
# 3  {'n_neighbors': 3, 'algorithm': 'ball_tree'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
results2[['param_n_neighbors','param_algorithm','mean_test_score']].sort_values(by='mean_test_score',ascending=False)
# Out:
#    param_n_neighbors param_algorithm  mean_test_score
# 1                  7         kd_tree         0.980000
# 2                  5            auto         0.973333
# 0                  3            auto         0.966667
# 3                  3       ball_tree         0.966667
